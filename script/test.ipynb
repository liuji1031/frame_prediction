# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('/home/ji/Dropbox/Robotics/ENPM809K_Fundamentals_in_AI_and_DL/Data/Data_2023-10-22_11-33-39_merge.txt')
# data = np.loadtxt('/home/ji/Dropbox/Robotics/ENPM809K_Fundamentals_in_AI_and_DL/Data_Test/Data_2023-10-26_10-25-07_merge.txt')

# %%
print(np.std(data,axis=0))
# Out:
# [0.80488084 0.9272317  1.21890248 0.07817036 0.03135062 0.10741344
#  3.01212941]

# %%
plt.plot(data)

# %%
plt.plot(data[:,1])

# %%
plt.plot(data)
